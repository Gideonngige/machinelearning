# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

df = pd.read_csv('hr.csv')
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Department', 'salary'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
dfle = df
dfle
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
dfle.salary = le.fit_transform(dfle.salary)
dfle
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
dfle.tail()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 14994                   151                   3              0     1
# 14995                   160                   3              0     1
# 14996                   143                   3              0     1
# 14997                   280                   4              0     1
# 14998                   158                   3              0     1
#
#        promotion_last_5years Department  salary
# 14994                      0    support       1
# 14995                      0    support       1
# ...

# %%
plt.bar(dfle.salary, dfle.left)
# Out:
# <BarContainer object of 14999 artists>

# %%
dfle.Department = le.fit_transform(dfle.Department)
dfle.Department
# Out:
# 0        7
# 1        7
# 2        7
# 3        7
# 4        7
#         ..
# 14994    8
# 14995    8
# 14996    8
# 14997    8
# 14998    8
# Name: Department, Length: 14999, dtype: int64

# %%
dfle
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
plt.bar(dfle.Department, dfle.left)
# Out:
# <BarContainer object of 14999 artists>

# %%
dfle
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df[['satisfaction_level','last_evaluation','salary', 'time_spend_company','promotion_last_5years']], df.left, train_size=0.8)

# %%
X_train
# Out:
#        satisfaction_level  last_evaluation  salary  time_spend_company  \
# 9966                 0.74             0.82       2                   2
# 410                  0.28             0.45       1                   4
# 7476                 0.65             0.48       0                   3
# 5798                 0.90             0.82       1                   2
# 54                   0.10             0.92       1                   4
# ...                   ...              ...     ...                 ...
# 9233                 0.63             0.94       2                   3
# 4303                 0.50             0.54       1                   3
# 5797                 0.21             0.99       1                   4
# 8383                 0.92             0.62       2                   2
# 11830                0.63             0.50       2                   4
#
#        promotion_last_5years
# 9966                       0
# 410                        0
# ...

# %%
X_test
# Out:
#        satisfaction_level  last_evaluation  salary  time_spend_company  \
# 11484                0.78             0.65       0                   3
# 1343                 0.44             0.54       1                   3
# 11707                0.43             0.66       0                   2
# 12008                0.89             1.00       1                   5
# 6158                 0.60             0.79       1                   2
# ...                   ...              ...     ...                 ...
# 9869                 0.77             0.71       0                   3
# 1505                 0.37             0.46       2                   3
# 5787                 0.16             0.80       2                   5
# 14811                0.77             0.98       1                   6
# 5571                 0.98             0.86       1                   2
#
#        promotion_last_5years
# 11484                      0
# 1343                       0
# ...

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([0, 0, 0, ..., 1, 0, 0], shape=(3000,))

# %%
X_test
# Out:
#        satisfaction_level  last_evaluation  salary  time_spend_company  \
# 11484                0.78             0.65       0                   3
# 1343                 0.44             0.54       1                   3
# 11707                0.43             0.66       0                   2
# 12008                0.89             1.00       1                   5
# 6158                 0.60             0.79       1                   2
# ...                   ...              ...     ...                 ...
# 9869                 0.77             0.71       0                   3
# 1505                 0.37             0.46       2                   3
# 5787                 0.16             0.80       2                   5
# 14811                0.77             0.98       1                   6
# 5571                 0.98             0.86       1                   2
#
#        promotion_last_5years
# 11484                      0
# 1343                       0
# ...

# %%
model.predict([[0.54,0.71,1,3,0]])
# Out:
# C:\Users\jtrip\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
dfle
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
dfle.tail()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 14994                   151                   3              0     1
# 14995                   160                   3              0     1
# 14996                   143                   3              0     1
# 14997                   280                   4              0     1
# 14998                   158                   3              0     1
#
#        promotion_last_5years  Department  salary
# 14994                      0           8       1
# 14995                      0           8       1
# ...

# %%
model.predict([[0.37,0.52,1,3,0]])
# Out:
# C:\Users\jtrip\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
model.score(X_test, y_test)
# Out:
# 0.757

# %%
model.predict([[0.37,0.52,3,0,1]])
# Out:
# C:\Users\jtrip\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
model.score(X_test, y_test)
# Out:
# 0.757

# %%
X_train.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'salary', 'time_spend_company',
#        'promotion_last_5years'],
#       dtype='object')

# %%
model.predict([[0.1,0.1,1,2,0]])
# Out:
# C:\Users\jtrip\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])
