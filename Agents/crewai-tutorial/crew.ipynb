# %%
from dotenv import load_dotenv
load_dotenv()

from crewai import  LLM
llm = LLM(
    model="gemini/gemini-2.0-flash",
    temperature=0.1
)
llm.call("Who invented transcendental meditation.")
# Out:
# 'Transcendental Meditation (TM) was popularized by **Maharishi Mahesh Yogi**.\n'

# %%
from crewai import Agent, Task, Crew

research_agent = Agent(
    role="Research Specialist",
    goal="Research interesting facts about the topic: {topic}",
    backstory="You are an expert at finding relevant and factual data.",
    verbose=True,
    llm=llm
)

writer_agent = Agent(
    role="Creative Writer",
    goal="Write a short blog summary using the research",
    backstory="You are skilled ar writing engaging summaries based on provided content",
    llm=llm,
    verbose=True
)

# %%
task1 = Task(
    description="Find 3-5 interesting and recent facts about {topic}",
    expected_output="A bullet list of 3-5 facts",
    agent=research_agent,
)

task2 = Task(
    description="Write a 100-word blog post summary about {topic} using the facts from the research.",
    expected_output="A blog post summary",
    agent=writer_agent,
    context=[task1],
)

crew = Crew(
    agents=[research_agent, writer_agent],
    tasks=[task1, task2],
    verbose=True,
)

crew.kickoff(inputs={"topic":"The future of electrical vehicles"})
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 4b153518-a011-460b-874c-9cb24dec5c49                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Task: Find 3-5 interesting and recent facts about The future of electrical vehicles                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Here are 5 interesting and recent facts about the future of electric vehicles:                                 │
# │                                                                                                                 │
# │  *   **Global EV Sales are Projected to Continue Growing:** Despite economic headwinds, global electric car     │
# │  sales are projected to grow significantly in 2024. One projection estimates 17 million electric vehicle sales  │
# │  worldwide, accounting for approximately 20% of all car sales. This indicates a continued strong shift towards  │
# │  electric mobility.                                                                                             │
# │                                                                                                                 │
# │  *   **Battery Technology Advancements are Key:** Solid-state batteries are emerging as a potential             │
# │  game-changer for EVs. These batteries promise higher energy density, faster charging times, and improved       │
# │  safety compared to traditional lithium-ion batteries. Several companies are investing heavily in solid-state   │
# │  battery research and development, with some anticipating commercial availability in the coming years.          │
# │                                                                                                                 │
# │  *   **Charging Infrastructure is Expanding but Needs Further Development:** The expansion of charging          │
# │  infrastructure is crucial for widespread EV adoption. While the number of public charging points is            │
# │  increasing, there's still a need for more chargers, especially fast chargers, in convenient locations.         │
# │  Governments and private companies are investing in expanding charging networks to address this challenge.      │
# │                                                                                                                 │
# │  *   **EVs are Becoming More Affordable:** The cost of EVs is decreasing, making them more accessible to a      │
# │  wider range of consumers. Battery prices, which are a major component of EV cost, have been declining.         │
# │  Government incentives and tax credits are also helping to lower the upfront cost of EVs.                       │
# │                                                                                                                 │
# │  *   **Electric Vehicle Technology is being applied to other forms of transportation:** While cars are the      │
# │  most common application of EV technology, electric propulsion is also being developed for trucks, buses,       │
# │  airplanes, and ships. This indicates a broader trend towards electrification across various transportation     │
# │  sectors.                                                                                                       │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: fe32cd36-a824-46d7-afa3-858bca0b5c06                                                                     │
# │  Agent: Research Specialist                                                                                     │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Task: Write a 100-word blog post summary about The future of electrical vehicles using the facts from the      │
# │  research.                                                                                                      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  **The Road Ahead: Promising Developments in the Electric Vehicle Landscape**                                   │
# │                                                                                                                 │
# │  The future of electric vehicles is charged with potential! Global EV sales are projected to surge in 2024,     │
# │  representing a significant portion of all car sales. Key to this growth are advancements in battery            │
# │  technology, particularly solid-state batteries, promising faster charging and improved safety. While charging  │
# │  infrastructure is expanding, further development is crucial. The good news? EVs are becoming more affordable   │
# │  thanks to declining battery costs and government incentives. Beyond cars, electric propulsion is               │
# │  revolutionizing trucks, buses, airplanes, and ships, signaling a widespread shift towards electrification      │
# │  across all transportation sectors.                                                                             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: bb092ce1-e182-40e6-890c-41f7cb2a2252                                                                     │
# │  Agent: Creative Writer                                                                                         │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 4b153518-a011-460b-874c-9cb24dec5c49                                                                       │
# │  Tool Args:                                                                                                     │
# │  Final Output: **The Road Ahead: Promising Developments in the Electric Vehicle Landscape**                     │
# │                                                                                                                 │
# │  The future of electric vehicles is charged with potential! Global EV sales are projected to surge in 2024,     │
# │  representing a significant portion of all car sales. Key to this growth are advancements in battery            │
# │  technology, particularly solid-state batteries, promising faster charging and improved safety. While charging  │
# │  infrastructure is expanding, further development is crucial. The good news? EVs are becoming more affordable   │
# │  thanks to declining battery costs and government incentives. Beyond cars, electric propulsion is               │
# │  revolutionizing trucks, buses, airplanes, and ships, signaling a widespread shift towards electrification      │
# │  across all transportation sectors.                                                                             │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# CrewOutput(raw='**The Road Ahead: Promising Developments in the Electric Vehicle Landscape**\n\nThe future of electric vehicles is charged with potential! Global EV sales are projected to surge in 2024, representing a significant portion of all car sales. Key to this growth are advancements in battery technology, particularly solid-state batteries, promising faster charging and improved safety. While charging infrastructure is expanding, further development is crucial. The good news? EVs are becoming more affordable thanks to declining battery costs and government incentives. Beyond cars, electric propulsion is revolutionizing trucks, buses, airplanes, and ships, signaling a widespread shift towards electrification across all transportation sectors.', pydantic=None, json_dict=None, tasks_output=[TaskOutput(description='Find 3-5 interesting and recent facts about The future of electrical vehicles', name=None, expected_output='A bullet list of 3-5 facts', summary='Find 3-5 interesting and recent facts about The future of...', raw="Here are 5 interesting and recent facts about the future of electric vehicles:\n\n*   **Global EV Sales are Projected to Continue Growing:** Despite economic headwinds, global electric car sales are projected to grow significantly in 2024. One projection estimates 17 million electric vehicle sales worldwide, accounting for approximately 20% of all car sales. This indicates a continued strong shift towards electric mobility.\n\n*   **Battery Technology Advancements are Key:** Solid-state batteries are emerging as a potential game-changer for EVs. These batteries promise higher energy density, faster charging times, and improved safety compared to traditional lithium-ion batteries. Several companies are investing heavily in solid-state battery research and development, with some anticipating commercial availability in the coming years.\n\n*   **Charging Infrastructure is Expanding but Needs Further Development:** The expansion of charging infrastructure is crucial for widespread EV adoption. While the number of public charging points is increasing, there's still a need for more chargers, especially fast chargers, in convenient locations. Governments and private companies are investing in expanding charging networks to address this challenge.\n\n*   **EVs are Becoming More Affordable:** The cost of EVs is decreasing, making them more accessible to a wider range of consumers. Battery prices, which are a major component of EV cost, have been declining. Government incentives and tax credits are also helping to lower the upfront cost of EVs.\n\n*   **Electric Vehicle Technology is being applied to other forms of transportation:** While cars are the most common application of EV technology, electric propulsion is also being developed for trucks, buses, airplanes, and ships. This indicates a broader trend towards electrification across various transportation sectors.", pydantic=None, json_dict=None, agent='Research Specialist', output_format=<OutputFormat.RAW: 'raw'>), TaskOutput(description='Write a 100-word blog post summary about The future of electrical vehicles using the facts from the research.', name=None, expected_output='A blog post summary', summary='Write a 100-word blog post summary about The future of...', raw='**The Road Ahead: Promising Developments in the Electric Vehicle Landscape**\n\nThe future of electric vehicles is charged with potential! Global EV sales are projected to surge in 2024, representing a significant portion of all car sales. Key to this growth are advancements in battery technology, particularly solid-state batteries, promising faster charging and improved safety. While charging infrastructure is expanding, further development is crucial. The good news? EVs are becoming more affordable thanks to declining battery costs and government incentives. Beyond cars, electric propulsion is revolutionizing trucks, buses, airplanes, and ships, signaling a widespread shift towards electri ...
